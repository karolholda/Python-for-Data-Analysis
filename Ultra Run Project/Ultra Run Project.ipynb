# %%
#import libraries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23576\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
#see the data that's been imorted

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7117634, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#clean up data

# %%
#only want USA Races, 50k or 50mi, 2020

# %%
#step 1 show 50mi or 50k
#50km
#50mi

# %%
df[df['Event distance/length'] == '50mi']
# Out:
#          Year of event     Event dates  \
# 55                2018      06.01.2018
# 56                2018      06.01.2018
# 57                2018      06.01.2018
# 58                2018      06.01.2018
# 59                2018      06.01.2018
# ...                ...             ...
# 7115712           2015  10.-11.10.2015
# 7115713           2015  10.-11.10.2015
# 7115714           2015  10.-11.10.2015
# 7115715           2015  10.-11.10.2015
# 7115716           2015  10.-11.10.2015
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#combine 50k/50mi with isin

# %%
df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                         Event name  \
# 0                 2018  06.01.2018                Selva Costera (CHI)
# 1                 2018  06.01.2018                Selva Costera (CHI)
# 2                 2018  06.01.2018                Selva Costera (CHI)
# 3                 2018  06.01.2018                Selva Costera (CHI)
# 4                 2018  06.01.2018                Selva Costera (CHI)
# ...                ...         ...                                ...
# 7117228           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117229           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117230           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117231           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117232           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']
# Out:
#          Year of event Event dates                          Event name  \
# 51923             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51924             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51925             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51926             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51927             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# ...                ...         ...                                 ...
# 6710397           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6710398           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6710399           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6710400           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6710401           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6710397    USA
# 6710398    USA
# 6710399    USA
# 6710400    USA
# 6710401    USA
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7117228           2015  09.10.2015
# 7117229           2015  09.10.2015
# 7117230           2015  09.10.2015
# 7117231           2015  09.10.2015
# 7117232           2015  09.10.2015
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#combine all filters together

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2 = df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]

# %%
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %%
#remove (USA) from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23576\3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head(10)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#clean up athlete age

# %%
df2['athlete_age'] = 2020 - df2['Athlete year of birth'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df2['athlete_age'] = 2020 - df2['Athlete year of birth'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
df2['Athlete year of birth'] = df2['Athlete year of birth'].fillna(0).astype('Int64')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23576\2938529722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete year of birth'] = df2['Athlete year of birth'].fillna(0).astype('Int64')

# %%
df2.loc[:, 'Athlete year of birth'] = df2['Athlete year of birth'].fillna(0).astype('Int64')

# %%
df2.head(10)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2['athlete_age'] = 2020 - df2['Athlete year of birth'].astype('Int64')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23576\2032940779.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = 2020 - df2['Athlete year of birth'].astype('Int64')

# %%
df2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
#remove age from athlete performance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split('h').str.get(0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23576\2439908443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split('h').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20            3:17:55
# 2539946                  50km                         20            4:02:32
# 2539947                  50km                         20            4:07:57
# 2539948                  50km                         20            4:22:02
# 2539949                  50km                         20            4:27:34
#
# ...

# %%
#drop columns: Athlete club, Athlete Country, Athlete year of birth, Athlete age category

# %%
df2 = df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df2 = df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df2.head(5)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20            3:17:55
# 2539946                  50km                         20            4:02:32
# 2539947                  50km                         20            4:07:57
# 2539948                  50km                         20            4:22:02
# 2539949                  50km                         20            4:27:34
#
# ...

# %%
#clean up null values

# %%
df2.isna().sum
# Out:
# <bound method DataFrame.sum of          Year of event  Event dates  Event name  Event distance/length  \
# 2539945          False        False       False                  False
# 2539946          False        False       False                  False
# 2539947          False        False       False                  False
# 2539948          False        False       False                  False
# 2539949          False        False       False                  False
# ...                ...          ...         ...                    ...
# 2760957          False        False       False                  False
# 2760958          False        False       False                  False
# 2760959          False        False       False                  False
# 2760960          False        False       False                  False
# 2760961          False        False       False                  False
#
#          Event number of finishers  Athlete performance  Athlete gender  \
# ...

# %%
df2 = df2.dropna()

# %%
df2.isna().sum
# Out:
# <bound method DataFrame.sum of          Year of event  Event dates  Event name  Event distance/length  \
# 2539945          False        False       False                  False
# 2539946          False        False       False                  False
# 2539947          False        False       False                  False
# 2539948          False        False       False                  False
# 2539949          False        False       False                  False
# ...                ...          ...         ...                    ...
# 2760957          False        False       False                  False
# 2760958          False        False       False                  False
# 2760959          False        False       False                  False
# 2760960          False        False       False                  False
# 2760961          False        False       False                  False
#
#          Event number of finishers  Athlete performance  Athlete gender  \
# ...

# %%
df2.shape
# Out:
# (26090, 10)

# %%
#check for duplicated values

# %%
duplicate_count = df2.duplicated().sum()

# %%
duplicate_count
# Out:
# 0

# %%
#reset index

# %%
df2.reset_index(drop = True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 26085           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26086           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26087           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26088           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26089           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#fix types

# %%
df2.dtypes
# Out:
# Year of event                 int64
# Event dates                  object
# Event name                   object
# Event distance/length        object
# Event number of finishers     int64
# Athlete performance          object
# Athlete gender               object
# Athlete average speed        object
# Athlete ID                    int64
# athlete_age                   Int64
# dtype: object

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    Int64
# dtype: object

# %%
#rename columns

# %%
#Year of event                  int64
#Event dates                   object
#Event name                    object
#Event distance/length         object
#Event number of finishers      int64
#Athlete performance           object
#Athlete gender                object
#Athlete average speed        float64
#Athlete ID                     int64
#athlete_age                    Int64

# %%
df2 = df2.rename(columns = {'Year of event':'year' ,
                            'Event dates':'race_day',
                            'Event name':'race_name',
                            'Event distance/length':'race_length',
                            'Event number of finishers':'race_nr_of_finishers',
                            'Athlete performance':'athlete_performance',
                            'Athlete gender':'athlete_gender',
                            'Athlete average speed':'athlete_avg_speed',
                            'Athlete ID':'athlete_id',
                 })

# %%
df2.head()
# Out:
#          year    race_day                                 race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         race_length  race_nr_of_finishers athlete_performance athlete_gender  \
# 2539945        50km                    20            3:17:55               M
# 2539946        50km                    20            4:02:32               M
# 2539947        50km                    20            4:07:57               M
# 2539948        50km                    20            4:22:02               M
# 2539949        50km                    20            4:27:34               M
#
#          athlete_avg_speed  athlete_id  athlete_age
# ...

# %%
df3 = df2[['race_day', 'race_name', 'race_length', 'race_nr_of_finishers', 'athlete_id', 'athlete_gender', 'athlete_age', 'athlete_performance', 'athlete_avg_speed', 'year']]

# %%
df3.head()
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#          race_nr_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2539945                    20       71287              M           29
# 2539946                    20      629508              M           39
# 2539947                    20       64838              M           21
# 2539948                    20      704450              M           37
# 2539949                    20      810281              M           43
#
#         athlete_performance  athlete_avg_speed  year
# ...

# %%
#find 2 races that I ran in 2020 - Sarasota | Everglades

# %%
df3[df3['race_name'] == 'Everglades 50 Mile Ultra Run ']
# Out:
#            race_day                      race_name race_length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591489  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# ...

# %%
df3['race_name'].str.strip()
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                             ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: race_name, Length: 26090, dtype: object

# %%
df3[df3['race_name'] == 'Everglades 50 Mile Ultra Run ']
# Out:
#            race_day                      race_name race_length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591489  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# ...

# %%
df3['race_name'] = df3['race_name'].str.strip()

# %%
df3[df3['race_name'] == 'Everglades 50 Mile Ultra Run']
# Out:
#            race_day                     race_name race_length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# 2591489  14.03.2020  Everglades 50 Mile Ultra Run        50mi
# ...

# %%
#charts and graphs

# %%
plot1 = sns.histplot(df3['race_length'])

# %%
plot2 = sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')

# %%
sns.displot(df3[df3['race_length'] == '50mi']['athlete_avg_speed'])

# %%
#distribution of average athlete speeds for races of 50 miles in length.

# %%
plot = sns.displot(df3[df3['race_length'] == '50mi']['athlete_avg_speed'])
plot.set_axis_labels("Avg Athlete Speed", "Nr Of Athletes")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot(data=df3, x='race_length', y='athlete_avg_speed', hue='athlete_gender')

# Axes labels
plt.xlabel("Race Length")  
plt.ylabel("Athlete Average Speed")  

plt.legend(title="Athlete Gender", loc="best")  #Lended Title
plt.show()

# %%
df3['athlete_age']

# %%
#Relationship Between Age and Average Speed

# %%
import seaborn as sns
import matplotlib.pyplot as plt

filtered_df = df3[df3['athlete_age'] <= 100]

sns.lmplot(data=filtered_df, x='athlete_age', y='athlete_avg_speed')

plt.xlabel("Athlete Age")
plt.ylabel("Athlete Average Speed")
plt.title("Relationship Between Age and Average Speed")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

filtered_df = df3[df3['athlete_age'] <= 100]

sns.lmplot(data=filtered_df, x='athlete_age', y='athlete_avg_speed', hue = 'athlete_gender')

plt.xlabel("Athlete Age")
plt.ylabel("Athlete Average Speed")
plt.title("Relationship Between Age and Average Speed")

plt.show()

# %%
#questions I want to find out from data

# %%
#Difference in speed for the 50km, 50mi male to female

# %%
df3.groupby(['race_length', 'athlete_gender'])['athlete_avg_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 7.083843
#              M                 7.737665
# 50mi         F                 6.829343
#              M                 7.253770
# Name: athlete_avg_speed, dtype: float64

# %%
#what age groups are the best in the 50m Race (20 + races min)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_avg_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182
# 40           7.310669    236
# 21           7.304658     38
# 20           7.293778     27
# 32           7.287969    162
# 39           7.283648    227
# 37           7.220493    221
# 27           7.201748    119
# 41           7.197017    179
# 45           7.130667    156
# 47           7.085410    156
# 44           7.052642    179
# 51           7.019379    124
# 46           6.897236    174
# 43           6.884225    187
# 52           6.847400    130
# ...

# %%
df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
df3['race_season'] = df3['race_month'].apply(
    lambda x: 'Winter' if x > 11 else 
              'Fall' if x > 8 else 
              'Summer' if x > 5 else 
              'Spring' if x > 2 else 
              'Winter'
)

# %%
df3.head()
# Out:
#            race_day                                race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition        50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition        50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition        50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition        50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition        50km
#
#          race_nr_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2539945                    20       71287              M           29
# 2539946                    20      629508              M           39
# 2539947                    20       64838              M           21
# 2539948                    20      704450              M           37
# 2539949                    20      810281              M           43
#
#         athlete_performance  athlete_avg_speed  year  race_month race_season
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

season_avg_speed = df3.groupby('race_season')['athlete_avg_speed'].mean().reset_index()


sns.barplot(data=season_avg_speed, x='race_season', y='athlete_avg_speed')

plt.xlabel("Season")
plt.ylabel("Average Speed")
plt.title("Impact of Season on Average Running Speed")
plt.show()

# %%
df3.groupby('race_season')['athlete_avg_speed'].agg(['mean']).sort_values('mean', ascending = False)
# Out:
#                  mean
# race_season
# Spring       7.672551
# Winter       7.519917
# Fall         7.403707
# Summer       6.872740

# %%
import seaborn as sns
import matplotlib.pyplot as plt

season_avg_speed = df3.groupby('race_season')['athlete_avg_speed'].mean().reset_index()

sns.lineplot(data=season_avg_speed, x='race_season', y='athlete_avg_speed', marker='o')

# Dodanie opisów osi i tytułu
plt.xlabel("Season")
plt.ylabel("Average Speed")
plt.title("Impact of Season on Average Running Speed")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Wykres liniowy z podziałem na płeć
sns.lineplot(data=season_gender_avg_speed, x='race_season', y='athlete_avg_speed', hue='athlete_gender', marker='o')

# Dodanie opisów osi i tytułu
plt.xlabel("Season")
plt.ylabel("Average Speed")
plt.title("Impact of Season and Gender on Average Running Speed")

# Wyświetlenie wykresu
plt.show()

# %%
season_race_nr_finishers = df3.groupby('race_season')['race_nr_of_finishers'].mean().reset_index()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Wykres liniowy z podziałem na płeć
sns.lineplot(data=season_race_nr_finishers, x='race_season', y='race_nr_of_finishers', marker='o')

# Dodanie opisów osi i tytułu
plt.xlabel("Season")
plt.ylabel("Race Number of Finishers")
plt.title("Impact of Season on Nr Of Race Finishers")

# Wyświetlenie wykresu
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

season_race_nr_finishers = df3.groupby(['race_season', 'athlete_gender'])['race_nr_of_finishers'].sum().reset_index()

# Wykres liniowy z podziałem na płeć
sns.lineplot(
    data=season_race_nr_finishers, 
    x='race_season', 
    y='race_nr_of_finishers', 
    hue='athlete_gender',  # Podział według płci
    marker='o'
)

# Dodanie opisów osi i tytułu
plt.xlabel("Season")
plt.ylabel("Race Number of Finishers")
plt.title("Impact of Season on Number of Race Finishers by Gender")

# Wyświetlenie wykresu
plt.show()
