# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
source_folder = 'Source Data'
print(os.listdir(source_folder))
# Out:
# ['Costs.xlsx', 'customers.csv', 'orders.csv', 'order_positions.csv', 'order_ratings.csv', 'order_returns.csv', 'products.csv', 'product_groups.csv']

# %% [markdown]
# ## Costs.xlsx

# %%
df_costs = pd.read_excel(os.path.join(source_folder, 'Costs.xlsx'),sheet_name='cost_forecast')
print(df_costs.info())
df_costs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cost_forecast_id  16 non-null     int64
#  1   year              16 non-null     int64
#  2   ship              16 non-null     object
#  3   sales             16 non-null     int64
#  4   cost_forecast     16 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 772.0+ bytes
# None
#    cost_forecast_id  year            ship   sales  cost_forecast
# 0                 1  2018     First Class   59278          70000
# 1                 2  2018        Same Day   18969          30000
# 2                 3  2018    Second Class   99676          70000
# 3                 4  2018  Standard Class  336453         300000
# 4                 5  2019     First Class   81893          70000

# %% [markdown]
# ## orders.csv

# %%
df_orders = pd.read_csv(os.path.join(source_folder, 'orders.csv'),sep=';')
print(df_orders.info())
df_orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5009 entries, 0 to 5008
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           5009 non-null   int64
#  1   customer_id        5009 non-null   int64
#  2   order_date         5009 non-null   object
#  3   shipping_date      5009 non-null   object
#  4   shipping_mode      5009 non-null   object
#  5   delivery_country   5009 non-null   object
#  6   delivery_city      5009 non-null   object
#  7   delivery_state     5009 non-null   object
#  8   delivery_zip_code  5009 non-null   int64
#  9   return             5009 non-null   int64
# dtypes: int64(4), object(6)
# memory usage: 391.5+ KB
# None
#    order_id  customer_id  order_date shipping_date   shipping_mode  \
# 0       328          166  04.12.2020    07.12.2020    Second Class
# 1       329          262  08.07.2020    12.07.2020    Second Class
# 2       330          728  06.11.2019    13.11.2019  Standard Class
# 3       331          111  05.07.2018    10.07.2018  Standard Class
# 4       332           25  11.05.2021    16.05.2021  Standard Class
#
#   delivery_country    delivery_city  delivery_state  delivery_zip_code  return
# 0    United States        Henderson        Kentucky              42420      37
# 1    United States      Los Angeles      California              90036       1
# 2    United States  Fort Lauderdale         Florida              33311      47
# 3    United States      Los Angeles      California              90032       7
# 4    United States          Concord  North Carolina              28027      14

# %% [markdown]
# ## order_positions.csv

# %%
df_order_positions = pd.read_csv(os.path.join(source_folder, 'order_positions.csv'), sep=';')
print(df_order_positions.info())
df_order_positions.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           9994 non-null   int64
#  1   order_position_id  9994 non-null   int64
#  2   product_id         9994 non-null   int64
#  3   item_quantity      9994 non-null   int64
#  4   position_discount  9994 non-null   float64
# dtypes: float64(1), int64(4)
# memory usage: 390.5 KB
# None
#    order_id  order_position_id  product_id  item_quantity  position_discount
# 0       328                108          13              2               0.00
# 1       328                109          57              3               0.00
# 2       329                110         960              2               0.00
# 3       330                111         328              5               0.45
# 4       330                112        1338              2               0.20

# %% [markdown]
# ## order_ratings.csv

# %%
df_order_ratings = pd.read_csv(os.path.join(source_folder, 'order_ratings.csv'), sep=';')
print(df_order_ratings.info())
df_order_ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  745 non-null    int64
#  1   rating    745 non-null    int64
# dtypes: int64(2)
# memory usage: 11.8 KB
# None
#    order_id  rating
# 0       330       5
# 1       339       5
# 2       353       1
# 3       363       2
# 4       376       5

# %% [markdown]
# ## order_returns.csv

# %%
df_order_returns = pd.read_csv(os.path.join(source_folder, 'order_returns.csv'), sep=';')
print(df_order_returns.info())
df_order_returns.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         103 non-null    int64
#  1   next_order_free  103 non-null    int64
# dtypes: int64(2)
# memory usage: 1.7 KB
# None
#    order_id  next_order_free
# 0       329                0
# 1       359                0
# 2       367                0
# 3       374                0
# 4       455                0

# %% [markdown]
# ## products.csv

# %%
import pandas as pd
import os

source_folder = "Source Data"
csv_path = os.path.join(source_folder, 'products.csv')

try:
    df_products = pd.read_csv(
        csv_path,
        sep=';',
        on_bad_lines='skip',  # Ignoruje linie z błędami
        encoding='utf-8'
    )
    print(df_products.info())
    print(df_products.head())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1893 entries, 0 to 1892
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     1893 non-null   int64
#  1   group_id       1893 non-null   int64
#  2   product_name   1893 non-null   object
#  3   product_price  1893 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 59.3+ KB
# None
#    product_id  group_id                                       product_name  \
# 0        1847        17  Ativa-D5772-2-Line-5.8GHz-Digital-Expandable-C...
# 1        1759        17  I-Needs-3d-Hello-Kitty-Hybrid-Silicone-Case-Co...
# 2        1829        17  Panasonic-KX-TG9541B-DECT-6.0-Digital-2-Line-E...
# 3        1745        17  iKross-Bluetooth-Portable-Keyboard-+-Cell-Phon...
# 4         413         5  Holmes-Cool-Mist-Humidifier-for-the-Whole-Hous...
#
#    product_price
# 0         164.99
# 1          11.96
# 2         149.99
# 3          20.95
# 4          19.90

# %% [markdown]
# ## product_groups.csv

# %%
df_product_groups = pd.read_csv(os.path.join(source_folder, 'product_groups.csv'), sep=';')
print(df_product_groups.info())
df_product_groups.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   group_id  17 non-null     int64
#  1   group     17 non-null     object
#  2   category  17 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 540.0+ bytes
# None
#    group_id        group         category
# 0         1    Bookcases        Furniture
# 1         2       Chairs        Furniture
# 2         3  Furnishings        Furniture
# 3         4       Tables        Furniture
# 4         5   Appliances  Office Supplies

# %% [markdown]
# ## CLEAN and JOIN DATA.csv

# %% [markdown]
# ## Clean before joining

# %%
# Orders #

# drop unnecessary columns from orders
df_orders = df_orders.drop(columns=['shipping_date', 'delivery_country', 'delivery_city', 'delivery_state', 'delivery_zip_code', 'return'])
df_orders.head()
# Out:
#    order_id  customer_id  order_date   shipping_mode
# 0       328          166  04.12.2020    Second Class
# 1       329          262  08.07.2020    Second Class
# 2       330          728  06.11.2019  Standard Class
# 3       331          111  05.07.2018  Standard Class
# 4       332           25  11.05.2021  Standard Class

# %%
# orders_returns #
# Add is returned flag
df_order_returns['is_returned'] = 1
df_order_returns.head()
# Out:
#    order_id  next_order_free  is_returned
# 0       329                0            1
# 1       359                0            1
# 2       367                0            1
# 3       374                0            1
# 4       455                0            1

# %% [markdown]
# ## Join Data

# %%
print("Kolumny w df_orders:", df_orders.columns)
print("Kolumny w df_order_positions:", df_order_positions.columns)
print("Kolumny w df_products:", df_products.columns)
# Out:
# Kolumny w df_orders: Index(['order_id', 'customer_id', 'order_date', 'shipping_mode'], dtype='object')
# Kolumny w df_order_positions: Index(['order_id', 'order_position_id', 'product_id', 'item_quantity',
#        'position_discount'],
#       dtype='object')
# Kolumny w df_products: Index(['product_id', 'group_id', 'product_name', 'product_price'], dtype='object')

# %%
# orders, order_positions, products (product group not needed for analysis)
df1 = pd.merge(
    pd.merge(df_orders, df_order_positions, on='order_id', how='inner'),
    df_products, on='product_id', how='inner'
)
df1.head()
# Out:
#    order_id  customer_id  order_date   shipping_mode  order_position_id  \
# 0       328          166  04.12.2020    Second Class                108
# 1       328          166  04.12.2020    Second Class                109
# 2       329          262  08.07.2020    Second Class                110
# 3       330          728  06.11.2019  Standard Class                111
# 4       330          728  06.11.2019  Standard Class                112
#
#    product_id  item_quantity  position_discount  group_id  \
# 0          13              2               0.00         1
# 1          57              3               0.00         2
# 2         960              2               0.00        10
# 3         328              5               0.45         4
# 4        1338              2               0.20        12
#
#                                         product_name  product_price
# 0                  Bush-Somerset-Collection-Bookcase         130.98
# 1  Hon-Deluxe-Fabric-Upholstered-Stacking-Chairs-...         243.98
# 2  Self-Adhesive-Address-Labels-for-Typewriters-b...           7.31
# 3      Bretford-CR4500-Series-Slim-Rectangular-Table         348.21
# 4                      Eldon-Fold-N-Roll-Cart-System          13.98

# %%
# add order_returns, order_ratings
df = pd.merge(
    pd.merge(df1, df_order_returns, on='order_id', how='left'),
    df_order_ratings, on='order_id', how='left'
)
df.head()
# Out:
#    order_id  customer_id  order_date   shipping_mode  order_position_id  \
# 0       328          166  04.12.2020    Second Class                108
# 1       328          166  04.12.2020    Second Class                109
# 2       329          262  08.07.2020    Second Class                110
# 3       330          728  06.11.2019  Standard Class                111
# 4       330          728  06.11.2019  Standard Class                112
#
#    product_id  item_quantity  position_discount  group_id  \
# 0          13              2               0.00         1
# 1          57              3               0.00         2
# 2         960              2               0.00        10
# 3         328              5               0.45         4
# 4        1338              2               0.20        12
#
#                                         product_name  product_price  \
# 0                  Bush-Somerset-Collection-Bookcase         130.98
# 1  Hon-Deluxe-Fabric-Upholstered-Stacking-Chairs-...         243.98
# 2  Self-Adhesive-Address-Labels-for-Typewriters-b...           7.31
# 3      Bretford-CR4500-Series-Slim-Rectangular-Table         348.21
# 4                      Eldon-Fold-N-Roll-Cart-System          13.98
#
#    next_order_free  is_returned  rating
# 0              NaN          NaN     NaN
# 1              NaN          NaN     NaN
# 2              0.0          1.0     NaN
# 3              NaN          NaN     5.0
# 4              NaN          NaN     5.0

# %%
#check join
df[df['is_returned'].notna() & df['rating'].notna()].head()
# Out:
#       order_id  customer_id  order_date   shipping_mode  order_position_id  \
# 661        637          651  30.11.2020        Same Day                772
# 938        777          684  08.01.2021  Standard Class               1049
# 939        777          684  08.01.2021  Standard Class               1050
# 2220      1417          470  24.08.2021  Standard Class               2334
# 2221      1417          470  24.08.2021  Standard Class               2335
#
#       product_id  item_quantity  position_discount  group_id  \
# 661          922              3                0.0         9
# 938          722              2                0.2         7
# 939          328              4                0.2         4
# 2220         945              2                0.2         9
# 2221        1804              1                0.2        17
#
#                                            product_name  product_price  \
# 661             OIC-Colored-Binder-Clips-Assorted-Sizes           3.58
# 938   Acco-Pressboard-Covers-with-Storage-Hooks-14-7...           3.05
# 939       Bretford-CR4500-Series-Slim-Rectangular-Table         348.21
# 2220                           Assorted-Color-Push-Pins           1.81
# 2221                                       Cisco-SPA301         155.99
#
#       next_order_free  is_returned  rating
# 661               0.0          1.0     4.0
# 938               0.0          1.0     5.0
# 939               0.0          1.0     5.0
# 2220              0.0          1.0     2.0
# 2221              0.0          1.0     2.0

# %% [markdown]
# ## Useful functions

# %%
def print_result(s):
    print('\n', '-' * len(s), '\n', s, '\n', '-' * len(s), '\n')

# %% [markdown]
# ## REQ1: Which product is returned most often?

# %%
# returned
df_prod_returned = df[df['is_returned'] == 1]
df_prod_returned_agg = df_prod_returned.groupby(['product_id', 'product_name']).agg(
    qty_returned=('item_quantity', 'sum'),
    orders_returned=('order_id', 'nunique')
)

# total
df_prod_total_agg = df.groupby(['product_id', 'product_name']).agg(
    qty_total = ('item_quantity', 'sum'),
    orders_total = ('order_id', 'nunique')
)

# join
df_prod_returned_agg_f = pd.merge(df_prod_returned_agg, df_prod_total_agg, on = ['product_id', 'product_name'], how='inner')

# add % share
df_prod_returned_agg_f['qty_return_prc'] = round((df_prod_returned_agg_f['qty_returned'] / df_prod_returned_agg_f['qty_total']) * 100, 2)
df_prod_returned_agg_f['orders_return_prc'] = round((df_prod_returned_agg_f['orders_returned'] / df_prod_returned_agg_f['orders_total']) * 100, 2)

# sort
df_prod_returned_agg_f = df_prod_returned_agg_f.sort_values(by='qty_returned', ascending=False)

# show result
print_result('Top 10 prodcts returned sorted by total returned quantity')
df_prod_returned_agg_f.head(10)
# Out:
#  ---------------------------------------------------------
#  Top 10 prodcts returned sorted by total returned quantity
#  ---------------------------------------------------------
#                                                                qty_returned  \
# product_id product_name
# 1734       Polycom-VVX-310-VoIP-phone                                    13
# 669        Avery-Durable-Binders                                         13
# 1128       Xerox-232                                                     11
# 996        Permanent-Self-Adhesive-File-Folder-Labels-for-...            11
# 125        Global-Super-Steno-Chair                                      10
# 1592       Logitech-910-002974-M325-Wireless-Mouse-for-Web...             9
# 150        6-Cubicle-Wall-Clock-Black                                     9
# 570        Prang-Drawing-Pencil-Set                                       9
# 1709       iOttie-XL-Car-Mount                                            9
# 1250       Wirebound-Message-Book-4-per-Page                              9
#
#                                                                orders_returned  \
# product_id product_name
# 1734       Polycom-VVX-310-VoIP-phone                                        2
# 669        Avery-Durable-Binders                                             2
# 1128       Xerox-232                                                         1
# 996        Permanent-Self-Adhesive-File-Folder-Labels-for-...                1
# 125        Global-Super-Steno-Chair                                          2
# 1592       Logitech-910-002974-M325-Wireless-Mouse-for-Web...                2
# 150        6-Cubicle-Wall-Clock-Black                                        1
# 570        Prang-Drawing-Pencil-Set                                          1
# 1709       iOttie-XL-Car-Mount                                               1
# 1250       Wirebound-Message-Book-4-per-Page                                 1
#
#                                                                qty_total  \
# product_id product_name
# 1734       Polycom-VVX-310-VoIP-phone                                 40
# 669        Avery-Durable-Binders                                      50
# 1128       Xerox-232                                                  19
# 996        Permanent-Self-Adhesive-File-Folder-Labels-for-...         29
# 125        Global-Super-Steno-Chair                                   30
# 1592       Logitech-910-002974-M325-Wireless-Mouse-for-Web...         52
# 150        6-Cubicle-Wall-Clock-Black                                 19
# 570        Prang-Drawing-Pencil-Set                                   22
# 1709       iOttie-XL-Car-Mount                                        14
# 1250       Wirebound-Message-Book-4-per-Page                          35
#
#                                                                orders_total  \
# product_id product_name
# 1734       Polycom-VVX-310-VoIP-phone                                     8
# 669        Avery-Durable-Binders                                         12
# 1128       Xerox-232                                                      4
# 996        Permanent-Self-Adhesive-File-Folder-Labels-for-...             6
# 125        Global-Super-Steno-Chair                                       7
# 1592       Logitech-910-002974-M325-Wireless-Mouse-for-Web...            15
# 150        6-Cubicle-Wall-Clock-Black                                     4
# 570        Prang-Drawing-Pencil-Set                                       4
# 1709       iOttie-XL-Car-Mount                                            2
# 1250       Wirebound-Message-Book-4-per-Page                              7
#
#                                                                qty_return_prc  \
# product_id product_name
# 1734       Polycom-VVX-310-VoIP-phone                                   32.50
# 669        Avery-Durable-Binders                                        26.00
# 1128       Xerox-232                                                    57.89
# 996        Permanent-Self-Adhesive-File-Folder-Labels-for-...           37.93
# 125        Global-Super-Steno-Chair                                     33.33
# 1592       Logitech-910-002974-M325-Wireless-Mouse-for-Web...           17.31
# 150        6-Cubicle-Wall-Clock-Black                                   47.37
# 570        Prang-Drawing-Pencil-Set                                     40.91
# 1709       iOttie-XL-Car-Mount                                          64.29
# 1250       Wirebound-Message-Book-4-per-Page                            25.71
#
#                                                                orders_return_prc
# product_id product_name
# 1734       Polycom-VVX-310-VoIP-phone                                      25.00
# 669        Avery-Durable-Binders                                           16.67
# 1128       Xerox-232                                                       25.00
# 996        Permanent-Self-Adhesive-File-Folder-Labels-for-...              16.67
# 125        Global-Super-Steno-Chair                                        28.57
# 1592       Logitech-910-002974-M325-Wireless-Mouse-for-Web...              13.33
# 150        6-Cubicle-Wall-Clock-Black                                      25.00
# 570        Prang-Drawing-Pencil-Set                                        25.00
# 1709       iOttie-XL-Car-Mount                                             50.00
# 1250       Wirebound-Message-Book-4-per-Page                               14.29

# %% [markdown]
# ## REQ2: High rating = customer returns?

# %%
# pick only needed columns and deduplicate
df_ratings = df[['order_id', 'customer_id', 'order_date', 'rating']].drop_duplicates().reset_index(drop=True)

# Dodanie kolumny z datą ostatniego zamówienia dla każdego klienta
df_ratings['last_order'] = df_ratings.groupby('customer_id')['order_date'].transform('max')

# Filtrowanie tylko tych zamówień, które nie są ostatnim zamówieniem
df_ratings = df_ratings[df_ratings['last_order'] != df_ratings['order_date']]

# Wypełnienie brakujących ocen wartością 'none'
df_ratings['rating'] = df_ratings['rating'].fillna('none')

# Robię groupby po 'rating' i liczę ile jest unikalnych klientów
df_rating_agg = df_ratings.groupby('rating')['customer_id'].nunique()

# convert to df for easier viz
df_rating_agg = df_rating_agg.reset_index()
df_rating_agg.columns = ['rating', 'unique_customers']

# %%
# vizualize
sns.barplot(x='rating', y='unique_customers', data=df_rating_agg, palette='Set2')

# Add Labels and Title
plt.xlabel('Rating')
plt.ylabel('Customers')
plt.title('Rating vs Customers')

print_result('High rating (5) is better than lower rating, however, no rating doesn\'t mean no return, quite the opposite usually.')
print(df_rating_agg)

# Show plot
plt.show()
# Out:
#  -------------------------------------------------------------------------------------------------------------------
#  High rating (5) is better than lower rating, however, no rating doesn't mean no return, quite the opposite usually.
#  -------------------------------------------------------------------------------------------------------------------
#
#   rating  unique_customers
# 0    1.0                67
# 1    2.0                63
# 2    3.0                65
# 3    4.0                58
# 4    5.0               282
# 5   none               776
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12796\3536348417.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rating', y='unique_customers', data=df_rating_agg, palette='Set2')

# %% [markdown]
# ## REQ3: Sales trend over months

# %%
print(df['order_date'].dtype)
# Out:
# object

# %%
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# %%
print(df['order_date'].dtype)
# Out:
# datetime64[ns]

# %%
# create sales KPIs

df['discount_abs'] = df['product_price'] * df['item_quantity'] * df['position_discount']
df['sales_gross'] = df['product_price'] * df['item_quantity']
df['sales_net'] = round(df['sales_gross'] - df['discount_abs'], 2)

# group to month
monthly_sales = df.groupby(df['order_date'].dt.to_period('M'))[['sales_net', 'sales_gross']].sum().reset_index()
monthly_sales.columns = ['Order Month', 'Net Sales', 'Gross Sales']

# Convert Order Month to str for better Look on the viz
monthly_sales['Order Month'] = monthly_sales['Order Month'].astype(str)

# %%
# vizualize 

plt.figure(figsize=(10, 6))
plt.plot(monthly_sales['Order Month'], monthly_sales['Net Sales'], label='Net Sales', color='green')
plt.plot(monthly_sales['Order Month'], monthly_sales['Gross Sales'], label='Gross Sales', color='blue')
plt.ylabel('Sales')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout() # looks better

# %% [markdown]
# ## REQ4: Shipping costs vs sales

# %%
# group sales to year
df_year_sales = df.groupby([df['order_date'].dt.year, 'shipping_mode'])[['sales_net', 'sales_gross']].sum().reset_index()
df_year_sales.columns = ['year', 'ship', 'Net Sales', 'Gross Sales']

# join with costs
df_sales_costs = pd.merge(df_year_sales, df_costs, on=['year', 'ship'], how='left')
df_sales_costs.columns = ['Year', 'Shipping Mode', 'Net Sales', 'Gross Sales', 'cost_forecast_id', 'Costs', 'sales']

df_sales_costs['Year'] = df_sales_costs['Year'].astype(int)

# show table
df_sales_costs.head()
# Out:
#    Year   Shipping Mode  Net Sales  Gross Sales  cost_forecast_id     Costs  \
# 0  2018     First Class   15956.46     20077.02               1.0   59278.0
# 1  2018        Same Day    6455.14      6940.47               2.0   18969.0
# 2  2018    Second Class   29093.49     34035.68               3.0   99676.0
# 3  2018  Standard Class   91628.90    121125.17               4.0  336453.0
# 4  2019     First Class   26618.09     31210.52               5.0   81893.0
#
#       sales
# 0   70000.0
# 1   30000.0
# 2   70000.0
# 3  300000.0
# 4   70000.0

# %%
df_sales_costs.head()
# Out:
#    Year   Shipping Mode  Net Sales  Gross Sales  cost_forecast_id     Costs  \
# 0  2018     First Class   15956.46     20077.02               1.0   59278.0
# 1  2018        Same Day    6455.14      6940.47               2.0   18969.0
# 2  2018    Second Class   29093.49     34035.68               3.0   99676.0
# 3  2018  Standard Class   91628.90    121125.17               4.0  336453.0
# 4  2019     First Class   26618.09     31210.52               5.0   81893.0
#
#       sales
# 0   70000.0
# 1   30000.0
# 2   70000.0
# 3  300000.0
# 4   70000.0

# %%
# melt unpivot ofr viz yealy overview

df_cs_melted = df_sales_costs.melt(
    id_vars=['Year', 'Shipping Mode'],
    value_vars=['Net Sales', 'Gross Sales', 'Costs'],
    var_name='KPI',
    value_name='USD'
)

df_cs_melted
# Out:
#     Year   Shipping Mode          KPI        USD
# 0   2018     First Class    Net Sales   15956.46
# 1   2018        Same Day    Net Sales    6455.14
# 2   2018    Second Class    Net Sales   29093.49
# 3   2018  Standard Class    Net Sales   91628.90
# 4   2019     First Class    Net Sales   26618.09
# 5   2019        Same Day    Net Sales   12589.19
# 6   2019    Second Class    Net Sales   34334.79
# 7   2019  Standard Class    Net Sales  105929.45
# 8   2020     First Class    Net Sales   33492.64
# 9   2020        Same Day    Net Sales   15385.72
# 10  2020    Second Class    Net Sales   48556.01
# 11  2020  Standard Class    Net Sales  119964.03
# 12  2021     First Class    Net Sales   43722.34
# 13  2021        Same Day    Net Sales   22073.83
# 14  2021    Second Class    Net Sales   46937.25
# 15  2021  Standard Class    Net Sales  155041.50
# 16  2022     First Class    Net Sales    1407.12
# 17  2022        Same Day    Net Sales    1463.14
# 18  2022    Second Class    Net Sales    8098.54
# 19  2022  Standard Class    Net Sales   18565.71
# 20  2018     First Class  Gross Sales   20077.02
# 21  2018        Same Day  Gross Sales    6940.47
# 22  2018    Second Class  Gross Sales   34035.68
# 23  2018  Standard Class  Gross Sales  121125.17
# 24  2019     First Class  Gross Sales   31210.52
# 25  2019        Same Day  Gross Sales   15771.76
# 26  2019    Second Class  Gross Sales   39375.68
# 27  2019  Standard Class  Gross Sales  129492.26
# 28  2020     First Class  Gross Sales   42979.87
# 29  2020        Same Day  Gross Sales   18447.74
# 30  2020    Second Class  Gross Sales   59585.66
# 31  2020  Standard Class  Gross Sales  143855.67
# 32  2021     First Class  Gross Sales   54736.30
# 33  2021        Same Day  Gross Sales   26595.23
# 34  2021    Second Class  Gross Sales   55574.45
# 35  2021  Standard Class  Gross Sales  193364.49
# 36  2022     First Class  Gross Sales    1758.36
# 37  2022        Same Day  Gross Sales    2277.89
# 38  2022    Second Class  Gross Sales    8685.77
# 39  2022  Standard Class  Gross Sales   28589.70
# 40  2018     First Class        Costs   59278.00
# 41  2018        Same Day        Costs   18969.00
# 42  2018    Second Class        Costs   99676.00
# 43  2018  Standard Class        Costs  336453.00
# 44  2019     First Class        Costs   81893.00
# 45  2019        Same Day        Costs   31442.00
# 46  2019    Second Class        Costs  115262.00
# 47  2019  Standard Class        Costs  352090.00
# 48  2020     First Class        Costs  109478.00
# 49  2020        Same Day        Costs   38202.00
# 50  2020    Second Class        Costs  144208.00
# 51  2020  Standard Class        Costs  427638.00
# 52  2021     First Class        Costs  169873.00
# 53  2021        Same Day        Costs   59575.00
# 54  2021    Second Class        Costs  168109.00
# 55  2021  Standard Class        Costs  501765.00
# 56  2022     First Class        Costs        NaN
# 57  2022        Same Day        Costs        NaN
# 58  2022    Second Class        Costs        NaN
# 59  2022  Standard Class        Costs        NaN

# %%
# viz yearly overview

# %%
sns.barplot(x='Year', y='USD', hue='KPI', data=df_cs_melted, palette='Set2', errorbar=None)
plt.xlabel('Year')
plt.ylabel('USD')
plt.legend(title='KPI')
print_result('Yearly summary. Costs lower than gross sales but higher than net sales. Reconsider discounts.')
plt.show()
# Out:
#  ---------------------------------------------------------------------------------------------
#  Yearly summary. Costs lower than gross sales but higher than net sales. Reconsider discounts.
#  ---------------------------------------------------------------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# llop melt over shipping mode and do viz for each

for mode in df_sales_costs['Shipping Mode'].unique():
    df_mode = df_sales_costs[df_sales_costs['Shipping Mode'] == mode]
    df_melted = df_melted.melt(
    id_vars=['Year'],
    value_vars=['Net Sales', 'Gross Sales', 'Costs'],
    var_name='KPI',
    value_name='USD'
)    

sns.barplot(x='Year', y='USD', hue='KPI', data=df_melted, palette='Set2', errorbar=None)
plt.xlabel('Year')
plt.ylabel('USD')
plt.legend(title='KPI')

print_result(f'{mode} Summary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[531], line 7
#       5 for mode in df_sales_costs['Shipping Mode'].unique():
#       6     df_mode = df_sales_costs[df_sales_costs['Shipping Mode'] == mode]
# ----> 7     df_melted = df_melted.melt(
#       8     id_vars=['Year'],
#       9     value_vars=['Net Sales', 'Gross Sales', 'Costs'],
#      10     var_name='KPI',
#      11     value_name='USD'
#      12 )
#      14 sns.barplot(x='Year', y='USD', hue='KPI', data=df_melted, palette='Set2', errorbar=None)
#      15 plt.xlabel('Year')
#
# NameError: name 'df_melted' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pętla przez każdy tryb wysyłki
for mode in df_sales_costs['Shipping Mode'].unique():
    # Filtrowanie danych tylko dla danego trybu wysyłki
    df_mode = df_sales_costs[df_sales_costs['Shipping Mode'] == mode]
    
    # Rozpuszczenie danych (melt) dla tego trybu
    df_mode_melted = df_mode.melt(
        id_vars=['Year'],
        value_vars=['Net Sales', 'Gross Sales', 'Costs'],
        var_name='KPI',
        value_name='USD'
    )
    
    # Wykres słupkowy
    sns.barplot(x='Year', y='USD', hue='KPI', data=df_mode_melted, palette='Set2', errorbar=None)
    plt.xlabel('Year')
    plt.ylabel('USD')
    plt.legend(title='KPI')
    
    # Wyświetlenie tytułu dla podsumowania (przykładowa funkcja do wyświetlania wyników)
    print(f'{mode} Summary')
    plt.show()
# Out:
# First Class Summary
# Same Day Summary
# Second Class Summary
# Standard Class Summary
